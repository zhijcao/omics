# %% [markdown]
# # Scientific entity name recognition using pretrained model for knowledge extraction and interpretation

# %%
import spacy  # spaCy is designed specifically for production use and helps you build applications that process and “understand” large volumes of text. 
              #It can be used to build information extraction or natural language understanding systems, or to pre-process text for deep learning.
import scispacy # A full spaCy pipeline and models for scientific/biomedical documents
from spacy import displacy
from scispacy.linking import EntityLinker #The EntityLinker is a SpaCy component which performs linking to a knowledge base. 
                                          #The linker simply performs a string overlap - based search (char-3grams) on named entities, 
                                          #comparing them with the concepts in a knowledge base using an approximate nearest neighbours search

# %%
text = "Cancer treatment with doxorubicin (DOX) can induce cumulative dose-dependent cardiotoxicity. \
           Currently, there are no specific biomarkers that can identify patients at risk during the initial \
           doses of chemotherapy. The aim of this study was to examine plasma cytokines/chemokines and potential \
           cardiovascular biomarkers for the prediction of DOX-induced cardiotoxicity. Plasma samples were collected before (T0), \
           and after the first (T1) and the second (T2) cycles of DOX-based chemotherapy of 27 breast cancer patients, \
           including five patients who presented with >10% decline of left ventricular ejection fraction (LVEF), \
           five patients with LVEF decline of 5-10%, and 17 patients who maintained normal LVEF at the end of chemotherapy \
           (240 mg/m2 cumulative dose of DOX from four cycles of treatment). Multiplex immunoassays were used to screen plasma \
           samples for 40 distinct chemokines, nine matrix metalloproteinases, 33 potential markers of cardiovascular diseases, \
           and the fourth-generation cardiac troponin T assay. The results showed that the patients with abnormal decline of LVEF (>10%) \
           had lower levels of CXCL6 and sICAM-1 and higher levels of CCL23 and CCL27 at T0; higher levels of CCL23 and lower levels of \
           CXCL5, CCL26, CXCL6, GM-CSF, CXCL1, IFN-γ, IL-2, IL-8, CXCL11, CXCL9, CCL17, and CCL25 at T1; and higher levels of MIF and CCL23 \
           at T2 than the patients who maintained normal LVEF. Patients with LVEF decline of 5-10% had lower plasma levels of CXCL1, CCL3, GDF-15, \
           and haptoglobin at T0; lower levels of IL-16, FABP3, and myoglobin at T1; and lower levels of myoglobin and CCL23 at T2 as compared to \
           the patients who maintained normal LVEF. This pilot study identified potential biomarkers that may help predict which patients are vulnerable to \
           DOX-induced cardiotoxicity although further validation is needed in a larger cohort of patients. Impact statement Drug-induced cardiotoxicity is\
           one of the major concerns in drug development and clinical practice. It is critical to detect potential cardiotoxicity early before onset of \
           symptomatic cardiac dysfunction or heart failure. Currently there are no qualified clinical biomarkers for the prediction of cardiotoxicity \
           caused by cancer treatment such as doxorubicin (DOX). By using multiplex immunoassays, we identified proteins with significantly changed \
           plasma levels in a group of breast cancer patients who were treated with DOX-based chemotherapy and produced cardiotoxicity. These proteins \
           were associated with immune response and were identified before DOX treatment or at early doses of treatment, thus they could be potential \
           predictive biomarkers of cardiotoxicity although further validation is required to warrant their clinical values."

# %%
nlp = spacy.load("en_core_sci_lg") # using pretrained model

# %%
nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
# Out:
# C:\Users\ZCao\AppData\Roaming\Python\Python38\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.20.3 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\ZCao\AppData\Roaming\Python\Python38\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.20.3 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
doc = nlp(text)
# Out:
# C:\Users\ZCao\AppData\Roaming\Python\Python38\site-packages\scispacy\candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# C:\Users\ZCao\AppData\Roaming\Python\Python38\site-packages\scispacy\candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]

# %%
cra = spacy.load("en_ner_craft_md") #F1 76.11	GGP, SO, TAXON, CHEBI, GO, CL : (cell types, chemicals, proteins, genes)
jnl = spacy.load("en_ner_jnlpba_md") #F1 71.62	DNA, CELL_TYPE, CELL_LINE, RNA, PROTEIN : (cell lines, cell types, DNAs, RNAs, proteins)
                                     
bc5 = spacy.load("en_ner_bc5cdr_md") #F1 84.49	DISEASE, CHEMICAL : ( chemicals and diseases)
bio = spacy.load("en_ner_bionlp13cg_md") #F1 77.75	AMINO_ACID, ANATOMICAL_SYSTEM, CANCER, CELL, CELLULAR_COMPONENT, 
                                         # DEVELOPING_ANATOMICAL_STRUCTURE, GENE_OR_GENE_PRODUCT, IMMATERIAL_ANATOMICAL_ENTITY, 
                                         # MULTI-TISSUE_STRUCTURE, ORGAN, ORGANISM, ORGANISM_SUBDIVISION, ORGANISM_SUBSTANCE, 
                                         # PATHOLOGICAL_FORMATION, SIMPLE_CHEMICAL, TISSUE : (cancer genetics)

# %%
cra.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
jnl.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
bc5.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
bio.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-7-ee7be15737ba> in <module>
#       1 cra.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
#       2 jnl.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
# ----> 3 bc5.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
#       4 bio.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
#
# ~\AppData\Roaming\Python\Python38\site-packages\spacy\language.py in add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     766                     lang_code=self.lang,
#     767                 )
# --> 768             pipe_component = self.create_pipe(
#     769                 factory_name,
#     770                 name=name,
#
# ~\AppData\Roaming\Python\Python38\site-packages\spacy\language.py in create_pipe(self, factory_name, name, config, raw_config, validate)
#     657         # We're calling the internal _fill here to avoid constructing the
#     658         # registered functions twice
# --> 659         resolved = registry.resolve(cfg, validate=validate)
#     660         filled = registry.fill({"cfg": cfg[factory_name]}, validate=validate)["cfg"]
#     661         filled = Config(filled)
#
# ~\AppData\Roaming\Python\Python38\site-packages\thinc\config.py in resolve(cls, config, schema, overrides, validate)
#     720         validate: bool = True,
#     721     ) -> Dict[str, Any]:
# --> 722         resolved, _ = cls._make(
#     723             config, schema=schema, overrides=overrides, validate=validate, resolve=True
#     724         )
#
# ~\AppData\Roaming\Python\Python38\site-packages\thinc\config.py in _make(cls, config, schema, overrides, resolve, validate)
#     769         if not is_interpolated:
#     770             config = Config(orig_config).interpolate()
# --> 771         filled, _, resolved = cls._fill(
#     772             config, schema, validate=validate, overrides=overrides, resolve=resolve
#     773         )
#
# ~\AppData\Roaming\Python\Python38\site-packages\thinc\config.py in _fill(cls, config, schema, validate, resolve, parent, overrides)
#     841                     # We don't want to try/except this and raise our own error
#     842                     # here, because we want the traceback if the function fails.
# --> 843                     getter_result = getter(*args, **kwargs)
#     844                 else:
#     845                     # We're not resolving and calling the function, so replace
#
# ~\AppData\Roaming\Python\Python38\site-packages\scispacy\linking.py in __init__(self, nlp, name, candidate_generator, resolve_abbreviations, k, threshold, no_definition_threshold, filter_for_definitions, max_entities_per_mention, linker_name)
#      82         Span.set_extension("kb_ents", default=[], force=True)
#      83
# ---> 84         self.candidate_generator = candidate_generator or CandidateGenerator(
#      85             name=linker_name
#      86         )
#
# ~\AppData\Roaming\Python\Python38\site-packages\scispacy\candidate_generation.py in __init__(self, ann_index, tfidf_vectorizer, ann_concept_aliases_list, kb, verbose, ef_search, name)
#     230         )
#     231
# --> 232         self.kb = kb or DEFAULT_KNOWLEDGE_BASES[name]()
#     233         self.verbose = verbose
#     234
#
# ~\AppData\Roaming\Python\Python38\site-packages\scispacy\linking_utils.py in __init__(self, file_path, types_file_path)
#      87     ):
#      88
# ---> 89         super().__init__(file_path)
#      90
#      91         self.semantic_type_tree: UmlsSemanticTypeTree = construct_umls_tree_from_tsv(
#
# ~\AppData\Roaming\Python\Python38\site-packages\scispacy\linking_utils.py in __init__(self, file_path)
#      75             for alias in unique_aliases:
#      76                 alias_to_cuis[alias].add(concept["concept_id"])
# ---> 77             self.cui_to_entity[concept["concept_id"]] = Entity(**concept)
#      78
#      79         self.alias_to_cuis: Dict[str, Set[str]] = {**alias_to_cuis}
#
# MemoryError:

# %%
cra_doc=cra(text)
jnl_doc=jnl(text)
bc5_doc=bc5(text)
bio_doc=bio(text)

# %%
displacy.render(cra_doc, style='ent')

# %%
displacy.render(jnl_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Cancer treatment with doxorubicin (DOX) can induce cumulative dose-dependent cardiotoxicity.            Currently, there are no specific biomarkers that can identify patients at risk during the initial            doses of chemotherapy. The aim of this study was to examine
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     plasma cytokines/chemokines
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
#  and potential            cardiovascular biomarkers for the prediction of DOX-induced cardiotoxicity. Plasma samples were collected before (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     T0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DNA</span>
# </mark>
# ),            and after the first (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     T1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DNA</span>
# </mark>
# ) and the second (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     T2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DNA</span>
# </mark>
# ) cycles of DOX-based chemotherapy of 27 breast cancer patients,            including five patients who presented with &gt;10% decline of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     left ventricular ejection fraction
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CELL_TYPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LVEF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# ),            five patients with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LVEF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
#  decline of 5-10%, and 17 patients who maintained normal LVEF at the end of chemotherapy            (240 mg/m2 cumulative dose of DOX from four cycles of treatment). Multiplex immunoassays were used to screen plasma            samples for 40 distinct
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chemokines
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# , nine
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     matrix metalloproteinases
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# , 33 potential markers of cardiovascular diseases,            and the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fourth-generation cardiac troponin T
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
#  assay. The results showed that the patients with abnormal decline of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LVEF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
#  (&gt;10%)            had lower levels of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CXCL6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sICAM-1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
#  and higher levels of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CCL23
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CCL27
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
#  at
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     T0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DNA</span>
# </mark>
# ; higher levels of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CCL23
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
#  and lower levels of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CXCL5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CCL26
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CXCL6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GM-CSF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CXCL1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padd

# %%
displacy.render(bc5_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cancer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  treatment with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     doxorubicin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
# ) can induce cumulative dose-dependent
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cardiotoxicity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# .            Currently, there are no specific biomarkers that can identify patients at risk during the initial            doses of chemotherapy. The aim of this study was to examine plasma cytokines/chemokines and potential            cardiovascular biomarkers for the prediction of DOX-induced
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cardiotoxicity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# . Plasma samples were collected before (T0),            and after the first (T1) and the second (T2) cycles of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOX-based
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  chemotherapy of 27
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breast cancer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  patients,            including five patients who presented with &gt;10% decline of left ventricular ejection fraction (LVEF),            five patients with LVEF decline of 5-10%, and 17 patients who maintained normal LVEF at the end of chemotherapy            (240 mg/m2 cumulative dose of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  from four cycles of treatment). Multiplex immunoassays were used to screen plasma            samples for 40 distinct chemokines, nine matrix metalloproteinases, 33 potential markers of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cardiovascular diseases
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
# ,            and the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fourth-generation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  cardiac troponin T assay. The results showed that the patients with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     abnormal decline of LVEF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  (&gt;10%)            had lower levels of CXCL6 and sICAM-1 and higher levels of CCL23 and CCL27 at T0; higher levels of CCL23 and lower levels of            CXCL5, CCL26, CXCL6, GM-CSF, CXCL1,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IFN-γ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IL-2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IL-8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
# , CXCL11, CXCL9, CCL17, and CCL25 at T1; and higher levels of MIF and CCL23            at T2 than the patients who maintained normal LVEF. Patients with LVEF decline of 5-10% had lower plasma levels of CXCL1, CCL3, GDF-15,            and haptoglobin at T0; lower levels of IL-16, FABP3, and myoglobin at T1; and lower levels of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     myoglobin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  and CCL23 at T2 as compared to            the patients who maintained normal LVEF. This pilot study identified potential biomarkers that may help predict which patients are vulnerable to            DOX-induced
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cardiotoxicity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  although further validation is needed in a larger cohort of patients. Impact statement Drug-induced
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cardiotoxicity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  is           one of the major concerns in drug development and clinical practice. It is critical to detect potential
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cardiotoxicity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  early before onset of            symptomatic
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cardiac dysfunction
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  or
# <mark class="enti

# %%
displacy.render(bio_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cancer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CANCER</span>
# </mark>
#  treatment with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     doxorubicin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIMPLE_CHEMICAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIMPLE_CHEMICAL</span>
# </mark>
# ) can induce cumulative dose-dependent cardiotoxicity.            Currently, there are no specific biomarkers that can identify
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     patients
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGANISM</span>
# </mark>
#  at risk during the initial            doses of chemotherapy. The aim of this study was to examine
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     plasma cytokines/chemokines
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGANISM_SUBSTANCE</span>
# </mark>
#  and potential            cardiovascular biomarkers for the prediction of DOX-induced cardiotoxicity.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Plasma samples
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGANISM_SUBSTANCE</span>
# </mark>
#  were collected before (T0),            and after the first (T1) and the second (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     T2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CANCER</span>
# </mark>
# ) cycles of DOX-based chemotherapy of 27
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     breast cancer patients
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CANCER</span>
# </mark>
# ,            including five
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     patients
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGANISM</span>
# </mark>
#  who presented with &gt;10% decline of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     left ventricular
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MULTI_TISSUE_STRUCTURE</span>
# </mark>
#  ejection fraction (LVEF),            five
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     patients
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGANISM</span>
# </mark>
#  with LVEF decline of 5-10%, and 17
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     patients
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGANISM</span>
# </mark>
#  who maintained normal LVEF at the end of chemotherapy            (240 mg/m2 cumulative dose of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIMPLE_CHEMICAL</span>
# </mark>
#  from four cycles of treatment). Multiplex immunoassays were used to screen
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     plasma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGANISM_SUBSTANCE</span>
# </mark>
# samples for 40 distinct chemokines, nine
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     matrix metalloproteinases
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
# , 33 potential markers of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cardiovascular
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ANATOMICAL_SYSTEM</span>
# </mark>
#  diseases,            and the fourth-generation
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cardiac troponin T
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CANCER</span>
# </mark>
#  assay. The results showed that the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     patients
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORGANISM</span>
# </mark>
#  with abnormal decline of LVEF (&gt;10%)            had lower levels of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CXCL6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sICAM-1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  and higher levels of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CCL23
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CCL27
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENE_OR_GENE_PRODUCT</s

# %% [markdown]
# ## Example: Li-Rong Yu et al: Immune response proteins as predictive biomarkers of doxorubicin-induced cardiotoxicity in breast cancer patients (abstract only)

# %% [markdown]
# ## Display recognized scientific entities

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cancer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     treatment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     doxorubicin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# ) can
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     induce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cumulative
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dose-dependent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cardiotoxicity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .            Currently, there are no specific
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     biomarkers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  that can identify
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     patients
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  at
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     risk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  during the initial
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     doses
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chemotherapy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# . The aim of this
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     study
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  was to examine
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     plasma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cytokines/chemokines
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     potential
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cardiovascular
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     biomarkers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  for the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     prediction
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOX-induced
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cardiotoxicity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Plasma samples
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  were collected before (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     T0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# ),            and after the first (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     T1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# ) and the second (
# <mark class="entity" style="background: #ddd; padding: 0.45e

# %%
entity = doc.ents[2]
entity
# Out:
# doxorubicin

# %% [markdown]
# ## Linked to GO

# %%
#display doxorubicin is linked to go with a score (char-3gram matching)
entity._.kb_ents
# Out:
# [('C3547938', 0.8894673585891724),
#  ('C3822556', 0.879368245601654),
#  ('C3549011', 0.8477047681808472)]

# %%
linker = nlp.get_pipe("scispacy_linker")
for go_ent in entity._.kb_ents:
    print(linker.kb.cui_to_entity[go_ent[0]])
# Out:
# CUI: C3547938, Name: doxorubicin transport
# Definition: The directed movement of a doxorubicin into, out of or within a cell, or between cells, by means of some agent such as a transporter or pore. [GOC:TermGenie, PMID:12057006, PMID:15090538, PMID:19063901, PMID:19651502, PMID:9651400]
# TUI(s): T043
# Aliases: (total: 2):
# 	 (1S,3S)-3,5,12-trihydroxy-3-(hydroxyacetyl)-10-methoxy-6,11-dioxo-1,2,3,4,6,11-hexahydrotetracen-1-yl 3-amino-2,3,6-trideoxy-alpha-L-lyxo-hexopyranoside transport, doxorubicine transport
# CUI: C3822556, Name: response to doxorubicin
# Definition: Any process that results in a change in state or activity of a cell or an organism (in terms of movement, secretion, enzyme production, gene expression, etc.) as a result of a doxorubicin stimulus. [GOC:dw, GOC:TermGenie, PMID:23648065]
# TUI(s): T043
# Aliases: (total: 0):
#
# CUI: C3549011, Name: doxorubicin metabolic process
# Definition: The chemical reactions and pathways involving doxorubicin, an anthracycline antibiotic, used in cancer chemotherapy. [CHEBI:28748]
# TUI(s): T044
# Aliases: (total: 0):
